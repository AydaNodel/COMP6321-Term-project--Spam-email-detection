# %% [markdown]
# # BERT Spam Classifier — End-to-End (Hugging Face + Transformers)
#
# This notebook walks through a clean, reproducible pipeline:
#
# 1. **Install necessary libraries**
# 2. **Import & configuration**
# 3. **Load dataset** (`bourigue/data_email_spam`)
# 4. **Normalize columns** to `text` and `label` (0=ham, 1=spam)
# 5. **Create train/validation/test splits** (stratified)
# 6. **Tokenize** with `bert-base-uncased`
# 7. **Train** with `Trainer`
# 8. **Evaluate** (accuracy, precision, recall, F1)
# 9. **Save** model & tokenizer
# 10. **Reload** and **predict** on sample inputs

# %% [markdown]
# ## Necessary libraries

# %%
# If running locally, uncomment the next line to install dependencies.
# In Colab, you can leave it as is or run it once.
# !pip install -U datasets transformers accelerate scikit-learn torch evaluate

# %% [markdown]
# ## Imports and configuration

# %%
import os
import re
import numpy as np
from typing import Dict, Any, Tuple

from datasets import load_dataset, DatasetDict, ClassLabel
from sklearn.model_selection import train_test_split

import torch
from transformers import (
    AutoTokenizer,
    AutoConfig,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer,
    pipeline,
    set_seed,
)

# --- Config (adjust as needed) ---
HF_DATASET = "bourigue/data_email_spam"
BASE_MODEL = "bert-base-uncased"
OUTPUT_DIR = "models/bert-spam"
MAX_LEN = 256
EPOCHS = 3
BATCH_SIZE = 16
LR = 2e-5
WEIGHT_DECAY = 0.01
WARMUP_RATIO = 0.06
SEED = 42

os.makedirs(OUTPUT_DIR, exist_ok=True)
set_seed(SEED)

# %% [markdown]
# ## Load the dataset

# %%
dataset_raw = load_dataset(HF_DATASET)
dataset_raw
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# spam_email_dataset.csv:   0%|          | 0.00/112M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/85782 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text_combined', 'label'],
#         num_rows: 85782
#     })
# })

# %% [markdown]
# ## Quick peek at a few rows

# %%
for split in dataset_raw:
    print(f"Split: {split}, size={len(dataset_raw[split])}")
    print(dataset_raw[split][0])
    break
# Out:
# Split: train, size=85782
# {'text_combined': 'fark rssfeedsspamassassintaintorg url httpwwwnewsisfreecomclick482680291717 date 20020926t0822400100 img httpwwwnewsisfreecomimagesfarkazcentralgif azcentral thu 26 sep 2002 152859 0000 teen dies starvation stepfather puts bus', 'label': 0}

# %% [markdown]
# ## Data preprocessing — normalize `text` and `label` columns

# %%
def guess_columns(example: Dict[str, Any]) -> Tuple[str, str]:
    text_candidates = ["text", "message", "email", "content", "body"]
    label_candidates = ["label", "labels", "category", "target", "spam"]

    keys = set(example.keys())
    text_key = next((k for k in text_candidates if k in keys), None)
    label_key = next((k for k in label_candidates if k in keys), None)

    if text_key is None:
        for k in example.keys():
            if isinstance(example[k], str):
                text_key = k
                break
    if label_key is None:
        for k in example.keys():
            if k != text_key and isinstance(example[k], (int, float, np.integer, np.floating, bool)):
                label_key = k
                break

    if text_key is None or label_key is None:
        raise ValueError(f"Could not infer text/label keys from example keys: {example.keys()}")
    return text_key, label_key

any_split = next(iter(dataset_raw.keys()))
first_row = dataset_raw[any_split][0]
text_key, label_key = guess_columns(first_row)
print(f"Inferred columns -> text: '{text_key}', label: '{label_key}'")

def clean_text(t: str) -> str:
    t = t.strip()
    t = re.sub(r"\s+", " ", t)
    return t

def to_int_label(val) -> int:
    if isinstance(val, (int, np.integer)):
        return int(val)
    if isinstance(val, str):
        low = val.lower()
        if low in {"spam", "1", "true", "yes"}:
            return 1
        if low in {"ham", "0", "false", "no"}:
            return 0
        return 1 if low != "ham" else 0
    if isinstance(val, bool):
        return int(val)
    return int(val)

def normalize_split(ds):
    return ds.map(
        lambda ex: {
            "text": clean_text(ex[text_key]),
            "label": to_int_label(ex[label_key]),
        },
        remove_columns=[c for c in ds.column_names if c not in [text_key, label_key]],
    )

normalized_splits = {split: normalize_split(ds) for split, ds in dataset_raw.items()}
normalized = DatasetDict(normalized_splits)
normalized
# Out:
# Inferred columns -> text: 'text_combined', label: 'label'
# Map:   0%|          | 0/85782 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text_combined', 'label', 'text'],
#         num_rows: 85782
#     })
# })

# %% [markdown]
# ## Train/Validation/Test splits (stratified)

# %%
# If there's no explicit test split, make one from the first available split
if "test" not in normalized:
    base_split_name = next(iter(normalized.keys()))
    base_split = normalized[base_split_name]
    labels = base_split["label"]
    idx_train, idx_test = train_test_split(
        np.arange(len(labels)),
        test_size=0.2,
        random_state=SEED,
        stratify=labels
    )
    normalized = DatasetDict({
        "train": base_split.select(idx_train),
        "test":  base_split.select(idx_test),
    })

# Carve out a validation split (10% of train), stratified
train_labels = normalized["train"]["label"]
idx_train, idx_val = train_test_split(
    np.arange(len(train_labels)),
    test_size=0.1,
    random_state=SEED,
    stratify=train_labels
)

dataset = DatasetDict({
    "train": normalized["train"].select(idx_train),
    "validation": normalized["train"].select(idx_val),
    "test": normalized["test"]
})

# Make labels nicer (ClassLabel)
dataset = dataset.cast_column("label", ClassLabel(names=["ham", "spam"]))
dataset
# Out:
# Casting the dataset:   0%|          | 0/61762 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/6863 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/17157 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text_combined', 'label', 'text'],
#         num_rows: 61762
#     })
#     validation: Dataset({
#         features: ['text_combined', 'label', 'text'],
#         num_rows: 6863
#     })
#     test: Dataset({
#         features: ['text_combined', 'label', 'text'],
#         num_rows: 17157
#     })
# })

# %% [markdown]
# ## Tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, use_fast=True)

def tokenize_batch(batch):
    return tokenizer(
        batch["text"],
        truncation=True,
        max_length=MAX_LEN,
        padding=False,  # dynamic padding via data collator
    )

tokenized = dataset.map(tokenize_batch, batched=True, remove_columns=["text"])
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
list(tokenized.keys()), tokenized["train"][0].keys()
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Map:   0%|          | 0/61762 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6863 [00:00<?, ? examples/s]
# Map:   0%|          | 0/17157 [00:00<?, ? examples/s]
# (['train', 'validation', 'test'],
#  dict_keys(['text_combined', 'label', 'input_ids', 'token_type_ids', 'attention_mask']))

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average="binary", zero_division=0)
    acc = accuracy_score(labels, preds)
    return {"accuracy": acc, "precision": precision, "recall": recall, "f1": f1}

# %% [markdown]
# ## Model and Trainer

# %%
# === Model & Trainer (GPU-friendly + version-agnostic) ===
import os, torch
from packaging import version
import transformers as _tf

# Use GPU in Colab if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Torch CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

num_labels = 2
id2label = {0: "ham", 1: "spam"}
label2id = {"ham": 0, "spam": 1}

config = AutoConfig.from_pretrained(
    BASE_MODEL, num_labels=num_labels, id2label=id2label, label2id=label2id
)
model = AutoModelForSequenceClassification.from_pretrained(BASE_MODEL, config=config).to(device)

# Try modern TrainingArguments first; fall back if your transformers is older
try:
    training_args = TrainingArguments(
        output_dir=os.path.join(OUTPUT_DIR, "trainer_runs"),
        logging_dir=os.path.join(OUTPUT_DIR, "logs"),
        learning_rate=LR,
        per_device_train_batch_size=BATCH_SIZE,
        per_device_eval_batch_size=BATCH_SIZE,
        num_train_epochs=EPOCHS,
        weight_decay=WEIGHT_DECAY,
        warmup_ratio=WARMUP_RATIO,          # safe on modern versions
        evaluation_strategy="epoch",        # <-- modern
        save_strategy="epoch",              # <-- modern
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        greater_is_better=True,
        fp16=torch.cuda.is_available(),     # use mixed precision on GPU
        report_to=[],                       # or ["tensorboard"]
    )
except TypeError as e:
    print("Falling back to legacy TrainingArguments (older transformers):", e)
    # Minimal, broadly compatible args for older versions (no evaluation/save strategy)
    base_kwargs = dict(
        output_dir=os.path.join(OUTPUT_DIR, "trainer_runs"),
        logging_dir=os.path.join(OUTPUT_DIR, "logs"),
        learning_rate=LR,
        per_device_train_batch_size=BATCH_SIZE,
        per_device_eval_batch_size=BATCH_SIZE,
        num_train_epochs=EPOCHS,
        logging_steps=100,
        save_steps=500,
        fp16=torch.cuda.is_available(),     # supported on many older versions too
        # no_cuda defaults to False, so GPU will be used if available
    )
    try:
        training_args = TrainingArguments(weight_decay=WEIGHT_DECAY, **base_kwargs)
    except TypeError:
        # some very old versions may not accept weight_decay
        training_args = TrainingArguments(**base_kwargs)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized["train"],
    eval_dataset=tokenized["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer
# Out:
# Torch CUDA available: True
# GPU: Tesla T4
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Falling back to legacy TrainingArguments (older transformers): TrainingArguments.__init__() got an unexpected keyword argument 'evaluation_strategy'
# /tmp/ipython-input-1384423609.py:61: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %% [markdown]
# ## Training

# %%
train_result = trainer.train()
train_result
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: satya-gmsv (satya-gmsv-concordia-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251018_025758-dq0iy5p0</code>
# Syncing run <strong><a href='https://wandb.ai/satya-gmsv-concordia-university/huggingface/runs/dq0iy5p0' target="_blank">wandering-mountain-3</a></strong> to <a href='https://wandb.ai/satya-gmsv-concordia-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/satya-gmsv-concordia-university/huggingface' target="_blank">https://wandb.ai/satya-gmsv-concordia-university/huggingface</a>
#  View run at <a href='https://wandb.ai/satya-gmsv-concordia-university/huggingface/runs/dq0iy5p0' target="_blank">https://wandb.ai/satya-gmsv-concordia-university/huggingface/runs/dq0iy5p0</a>
#     <div>
#
#       <progress value='11583' max='11583' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11583/11583 1:01:43, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.337900</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.176000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.128300</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.130200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.124200</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.103600</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.114900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.084100</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.108100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.087100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.084800</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.080400</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.073700</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.060600</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.085300</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.055900</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.055400</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.053600</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.063800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.043100</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.082300</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.033200</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.066000</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.037400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.056800</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.048800</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.040100</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.042900</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.043800</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.043000</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.052400</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.042400</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.046000</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.039000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.032500</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.051500</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.024800</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.050700</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.034300</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.015700</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.015700</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.017400</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.016500</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.014400</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.006800</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.016400</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.018500</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.013300</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.033300</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.034100</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.018400</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.025200</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.017700</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.015400</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.024300</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.029700</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.007700</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.023200</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.006500</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.017500</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>0.009400</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.018800</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.008900</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.030800</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>0.013400</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.014100</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.015400</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.005700</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>0.006800</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.005100</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.007100</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.004600</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>8900</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>9100</td>
#       <td>0.006000</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>9300</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>9700</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>9800</td>
#       <td>0.005400</td>
#     </tr>
#     <tr>
#       <td>9900</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>10100</td>
#       <td>0.009700</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>10300</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>0.007800</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10600</td>
#       <td>0.007500</td>
#     </tr>
#     <tr>
#       <td>10700</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>10900</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.003500</td>
#     </tr>
#     <tr>
#       <td>11100</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>11300</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>11400</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.004300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=11583, training_loss=0.03135137342808727, metrics={'train_runtime': 3762.8761, 'train_samples_per_second': 49.241, 'train_steps_per_second': 3.078, 'total_flos': 2.436219878229096e+16, 'train_loss': 0.03135137342808727, 'epoch': 3.0})

# %% [markdown]
# ## Evaluation on validation and test sets

# %%
val_metrics = trainer.evaluate(tokenized["validation"])
test_metrics = trainer.evaluate(tokenized["test"])

print("Validation metrics:", val_metrics)
print("Test metrics:", test_metrics)
# Out:
#     <div>
#
#       <progress value='1502' max='429' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [429/429 01:27]
#     </div>
# Validation metrics: {'eval_loss': 0.033346664160490036, 'eval_accuracy': 0.9943173539268542, 'eval_precision': 0.9964881474978051, 'eval_recall': 0.9921328671328671, 'eval_f1': 0.994305738063951, 'eval_runtime': 25.0558, 'eval_samples_per_second': 273.909, 'eval_steps_per_second': 17.122, 'epoch': 3.0}
# Test metrics: {'eval_loss': 0.03302673622965813, 'eval_accuracy': 0.9944046161916419, 'eval_precision': 0.9967205434527993, 'eval_recall': 0.9920727442294242, 'eval_f1': 0.9943912129002104, 'eval_runtime': 62.465, 'eval_samples_per_second': 274.666, 'eval_steps_per_second': 17.178, 'epoch': 3.0}

# %% [markdown]
# ## Save model and tokenizer

# %%
trainer.save_model(OUTPUT_DIR)   # saves model & config
tokenizer.save_pretrained(OUTPUT_DIR)
print(f"Saved to: {OUTPUT_DIR}")
# Out:
# Saved to: models/bert-spam

# %%
# Zip the saved model folder
# !zip -r bert-spam-model.zip {OUTPUT_DIR}

# Download to your local machine
from google.colab import files
files.download("bert-spam-model.zip")
# Out:
#   adding: models/bert-spam/ (stored 0%)
#   adding: models/bert-spam/vocab.txt (deflated 53%)
#   adding: models/bert-spam/config.json (deflated 50%)
#   adding: models/bert-spam/logs/ (stored 0%)
#   adding: models/bert-spam/logs/events.out.tfevents.1760760017.38fc27add6e2.972.1 (deflated 47%)
#   adding: models/bert-spam/logs/events.out.tfevents.1760756222.38fc27add6e2.972.0 (deflated 67%)
#   adding: models/bert-spam/training_args.bin (deflated 54%)
#   adding: models/bert-spam/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/trainer_state.json (deflated 72%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/trainer_state.json (deflated 79%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/trainer_state.json (deflated 77%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/trainer_state.json (deflated 77%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-7000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/trainer_state.json (deflated 77%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/trainer_state.json (deflated 77%)
#   adding: models/bert-spam/trainer_runs/checkpoint-5500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-6500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/trainer_state.json (deflated 77%)
#   adding: models/bert-spam/trainer_runs/checkpoint-4500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/trainer_state.json (deflated 74%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/optimizer.pt (deflated 12%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/trainer_state.json (deflated 70%)
#   adding: models/bert-spam/trainer_runs/checkpoint-1000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-8500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/trainer_state.json (deflated 79%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-10000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/trainer_state.json (deflated 79%)
#   adding: models/bert-spam/trainer_runs/checkpoint-11583/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/trainer_state.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/trainer_state.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-2500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/trainer_state.json (deflated 76%)
#   adding: models/bert-spam/trainer_runs/checkpoint-3500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/optimizer.pt (deflated 13%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/trainer_state.json (deflated 65%)
#   adding: models/bert-spam/trainer_runs/checkpoint-500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9000/model.safetensors (deflated 7%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/ (stored 0%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/vocab.txt (deflated 53%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/config.json (deflated 50%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/optimizer.pt (deflated 11%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/rng_state.pth (deflated 26%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/training_args.bin (deflated 54%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/tokenizer.json (deflated 71%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/scheduler.pt (deflated 61%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/scaler.pt (deflated 64%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/trainer_state.json (deflated 78%)
#   adding: models/bert-spam/trainer_runs/checkpoint-9500/model.safetensors (deflated 7%)
#   adding: models/bert-spam/tokenizer_config.json (deflated 75%)
#   adding: models/bert-spam/special_tokens_map.json (deflated 42%)
#   adding: models/bert-spam/model.safetensors (deflated 7%)

# %% [markdown]
# ## Reload the saved model and predict on sample inputs

# %%
clf = pipeline(
    "text-classification",
    model=OUTPUT_DIR,
    tokenizer=OUTPUT_DIR,
    device=0 if torch.cuda.is_available() else -1,
    truncation=True
)

samples = [
    "Congratulations! You've won a $1000 gift card. Click the link to claim now.",
    "Hey, are we still on for lunch tomorrow at noon?",
    "URGENT: Your account will be suspended. Verify here: http://scam.example",
]

for s in samples:
    pred = clf(s, top_k=None)[0]
    print(f"TEXT: {s}\nPREDICTION: {pred['label']}  (score={pred['score']:.4f})\n")
# Out:
# Device set to use cuda:0
# TEXT: Congratulations! You've won a $1000 gift card. Click the link to claim now.
# PREDICTION: spam  (score=0.9998)
#
# TEXT: Hey, are we still on for lunch tomorrow at noon?
# PREDICTION: ham  (score=0.9975)
#
# TEXT: URGENT: Your account will be suspended. Verify here: http://scam.example
# PREDICTION: spam  (score=0.9994)

# %%
samples = [
    # Promotions / obvious spam
    "🔥 LIMITED TIME OFFER: Get 90% OFF on all items! Redeem now: http://bit.ly/xyz",
    "You’ve been selected for a FREE iPhone 15 Pro. Confirm your address!",
    "Winner! Claim your $500 Walmart gift card within 24 hours.",
    "URGENT: Your Netflix account will be cancelled. Update payment at http://netflix-payments.example",
    "Final notice: We attempted to deliver your parcel. Pay customs fee: http://tracking-fee.example",

    # Phishing / credential harvest
    "Security Alert: Multiple login attempts detected. Verify your identity here: https://secure-login.example",
    "Your mailbox is almost full. Increase your storage now to avoid losing emails.",
    "We suspended your banking account due to suspicious activity. Download the attached form and verify.",
    "Two-factor reset requested. If this wasn't you, re-enter your password to cancel.",

    # Ham: personal / school / work
    "Hey, can you send me the slides from yesterday’s class? I missed the last 10 minutes.",
    "Mom’s birthday dinner is at 7pm on Friday. Can you pick up the cake?",
    "I pushed the latest changes to the repo—check the PR and leave comments when free.",
    "Great meeting today. Let’s finalize the budget sheet by Tuesday and sync with finance.",
    "Reminder: Project stand-up tomorrow at 9:30 AM in Room 214.",

    # Borderline marketing (legit newsletter style)
    "Weekly Digest: Top 10 data engineering articles you should read",
    "Your order #948231 has shipped. Track your package here.",
    "Thanks for subscribing! Your 10% discount code is WELCOME10.",
    "Status update: Your return has been received. Refund will be processed in 5–7 days.",

    # Obfuscated / spammy tricks
    "C0ngr@tulations!!! You w0n a pr1ze. Cl1ck h3re n0w!!!",
    "Get r.i.c.h quick with our guaranteed system. No skills needed.",
    "This is not a scam. We just need your bank info to transfer the funds.",

    # Social / calendar / transactional ham
    "Google Calendar: Event invitation — ML Study Group, Monday 6–7 PM.",
    "Your verification code is 482199. Do not share this with anyone.",
    "Invoice INV-1042 is due on 11/05. View or pay online.",
    "Your Uber is arriving now. Driver: Alex (Toyota Corolla, Black).",
    "We received your support request (#39201). Our team will reply within 24 hours.",

    # Foreign language + mixed
    "Oferta especial por tiempo limitado: 70% de descuento en cursos online.",
    "Bonjour, pouvez-vous confirmer votre présence à la réunion de demain ?",
    "Пожалуйста, подтвердите адрес доставки для вашего заказа.",
]

# Run in batch for speed
preds = clf(samples, truncation=True)
for s, p in zip(samples, preds):
    print(f"TEXT: {s}\nPREDICTION: {p['label']}  (score={p['score']:.4f})\n")
# Out:
# TEXT: 🔥 LIMITED TIME OFFER: Get 90% OFF on all items! Redeem now: http://bit.ly/xyz
# PREDICTION: spam  (score=1.0000)
#
# TEXT: You’ve been selected for a FREE iPhone 15 Pro. Confirm your address!
# PREDICTION: spam  (score=0.9998)
#
# TEXT: Winner! Claim your $500 Walmart gift card within 24 hours.
# PREDICTION: spam  (score=1.0000)
#
# TEXT: URGENT: Your Netflix account will be cancelled. Update payment at http://netflix-payments.example
# PREDICTION: spam  (score=0.9998)
#
# TEXT: Final notice: We attempted to deliver your parcel. Pay customs fee: http://tracking-fee.example
# PREDICTION: spam  (score=0.9978)
#
# TEXT: Security Alert: Multiple login attempts detected. Verify your identity here: https://secure-login.example
# PREDICTION: spam  (score=0.9964)
#
# TEXT: Your mailbox is almost full. Increase your storage now to avoid losing emails.
# PREDICTION: spam  (score=0.9978)
#
# TEXT: We suspended your banking account due to suspicious activity. Download the attached form and verify.
# PREDICTION: spam  (score=0.9998)
#
# TEXT: Two-factor reset requested. If this wasn't you, re-enter your password to cancel.
# PREDICTION: ham  (score=0.9978)
#
# TEXT: Hey, can you send me the slides from yesterday’s class? I missed the last 10 minutes.
# PREDICTION: ham  (score=0.9987)
#
# TEXT: Mom’s birthday dinner is at 7pm on Friday. Can you pick up the cake?
# PREDICTION: ham  (score=0.9979)
#
# TEXT: I pushed the latest changes to the repo—check the PR and leave comments when free.
# PREDICTION: ham  (score=0.9867)
#
# TEXT: Great meeting today. Let’s finalize the budget sheet by Tuesday and sync with finance.
# PREDICTION: ham  (score=0.9998)
#
# TEXT: Reminder: Project stand-up tomorrow at 9:30 AM in Room 214.
# PREDICTION: ham  (score=0.9996)
#
# TEXT: Weekly Digest: Top 10 data engineering articles you should read
# PREDICTION: ham  (score=0.9994)
#
# TEXT: Your order #948231 has shipped. Track your package here.
# PREDICTION: ham  (score=0.9376)
#
# TEXT: Thanks for subscribing! Your 10% discount code is WELCOME10.
# PREDICTION: ham  (score=0.9091)
#
# TEXT: Status update: Your return has been received. Refund will be processed in 5–7 days.
# PREDICTION: spam  (score=0.9601)
#
# TEXT: C0ngr@tulations!!! You w0n a pr1ze. Cl1ck h3re n0w!!!
# PREDICTION: spam  (score=1.0000)
#
# TEXT: Get r.i.c.h quick with our guaranteed system. No skills needed.
# PREDICTION: spam  (score=1.0000)
#
# TEXT: This is not a scam. We just need your bank info to transfer the funds.
# PREDICTION: spam  (score=0.9982)
#
# TEXT: Google Calendar: Event invitation — ML Study Group, Monday 6–7 PM.
# PREDICTION: ham  (score=1.0000)
#
# TEXT: Your verification code is 482199. Do not share this with anyone.
# PREDICTION: spam  (score=0.9925)
#
# TEXT: Invoice INV-1042 is due on 11/05. View or pay online.
# PREDICTION: spam  (score=1.0000)
#
# TEXT: Your Uber is arriving now. Driver: Alex (Toyota Corolla, Black).
# PREDICTION: ham  (score=0.8277)
#
# TEXT: We received your support request (#39201). Our team will reply within 24 hours.
# PREDICTION: ham  (score=0.9988)
#
# TEXT: Oferta especial por tiempo limitado: 70% de descuento en cursos online.
# PREDICTION: spam  (score=1.0000)
#
# TEXT: Bonjour, pouvez-vous confirmer votre présence à la réunion de demain ?
# PREDICTION: spam  (score=0.9988)
#
# TEXT: Пожалуйста, подтвердите адрес доставки для вашего заказа.
# PREDICTION: spam  (score=0.9990)

# %% [markdown]
# ## (Optional) Helper: classify your own text

# %%
def classify(text: str):
    res = clf(text, top_k=None)[0]
    print(f"Prediction: {res['label']} (score={res['score']:.4f})")
    return res

# Example:
classify("Limited time offer!!! Reply STOP to unsubscribe.")
# Out:
# Prediction: spam (score=1.0000)
# {'label': 'spam', 'score': 0.9999948740005493}
